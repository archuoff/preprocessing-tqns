# %% [markdown]
# <a href="https://colab.research.google.com/github/archuoff/preprocessing-tqns/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
Df1=pd.DataFrame({'name':['Archu','Aravind','gayu','monish'],'rollno':[12,14,15,16],'age':[19,20,16,24]})
Df2=pd.DataFrame({'marks':[20,25,30,28]})
result = pd.concat([Df1, Df2], axis=1)

print(result)
print('\n')
del result['age']
print(result)
print('\n')
df3=pd.DataFrame([['Damu',67,80],['koki',76,90]],columns=['name','rollno','marks'])
pd.concat([result, df3], axis=1)
print(result)
print('\n')

Df1=pd.DataFrame({'name':['Archu','Aravind','gayu','monish'],'rollno':[12,14,15,16],'age':[19,20,16,24]})
Df2=pd.DataFrame({'name':['Archu','Aravind','gayu','monish'],'rollno':[12,14,15,16],'age':[19,20,16,24]})
print(pd.merge(Df1,Df2,on='age'))
print('\n')

df1=pd.DataFrame(np.random.randn(3,2),index=[1,3,4],columns=['col1','col2'])
print(df1.sort_values(by='col1'))
# Out:
#       name  rollno  age  marks
# 0    Archu      12   19     20
# 1  Aravind      14   20     25
# 2     gayu      15   16     30
# 3   monish      16   24     28
#
#
#       name  rollno  marks
# 0    Archu      12     20
# 1  Aravind      14     25
# 2     gayu      15     30
# 3   monish      16     28
#
#
#       name  rollno  marks
# 0    Archu      12     20
# 1  Aravind      14     25
# 2     gayu      15     30
# 3   monish      16     28
#
#
#     name_x  rollno_x  age   name_y  rollno_y
# 0    Archu        12   19    Archu        12
# 1  Aravind        14   20  Aravind        14
# 2     gayu        15   16     gayu        15
# 3   monish        16   24   monish        16
#
#
#        col1      col2
# 3 -0.988290 -0.038138
# 4 -0.540232  1.849528
# 1  0.161174 -0.039076

# %%
from pandas.core.arrays.arrow import dtype
import pandas as pd
df=pd.read_csv('/content/iris.data.csv')
print(df.to_string())
df1=pd.DataFrame(df)
df2=pd.Series([1,2,3])
print('\n')
print(df1.columns)
print(df1.shape)
print(df2.dtype)
# Resetting the index before displaying the row
print(df1.loc[1].to_string(index=False))
print('\n')
#for index, row in df1.iterrows():
    #print(row)
print('\n')
d=df['3.5']/5
print(d)
# Out:
#      5.1  3.5  1.4  0.2      Iris-setosa
# 0    4.9  3.0  1.4  0.2      Iris-setosa
# 1    4.7  3.2  1.3  0.2      Iris-setosa
# 2    4.6  3.1  1.5  0.2      Iris-setosa
# 3    5.0  3.6  1.4  0.2      Iris-setosa
# 4    5.4  3.9  1.7  0.4      Iris-setosa
# 5    4.6  3.4  1.4  0.3      Iris-setosa
# 6    5.0  3.4  1.5  0.2      Iris-setosa
# 7    4.4  2.9  1.4  0.2      Iris-setosa
# 8    4.9  3.1  1.5  0.1      Iris-setosa
# 9    5.4  3.7  1.5  0.2      Iris-setosa
# 10   4.8  3.4  1.6  0.2      Iris-setosa
# 11   4.8  3.0  1.4  0.1      Iris-setosa
# 12   4.3  3.0  1.1  0.1      Iris-setosa
# 13   5.8  4.0  1.2  0.2      Iris-setosa
# 14   5.7  4.4  1.5  0.4      Iris-setosa
# 15   5.4  3.9  1.3  0.4      Iris-setosa
# 16   5.1  3.5  1.4  0.3      Iris-setosa
# 17   5.7  3.8  1.7  0.3      Iris-setosa
# 18   5.1  3.8  1.5  0.3      Iris-setosa
# 19   5.4  3.4  1.7  0.2      Iris-setosa
# 20   5.1  3.7  1.5  0.4      Iris-setosa
# 21   4.6  3.6  1.0  0.2      Iris-setosa
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/iris.data.csv')
d=df.sort_values(['3.5'])
print(d)
print('\n')
df1=pd.DataFrame([['ar','br','cr'],[23,34,67],[56,67,78]],index=['x','y','z'],columns=['a','b','c'])
print(df1)
print('\n')
df1.to_excel('d:\pandas_to_excel.xlsx',sheet_name='new_sheet_name')
df1.to_excel('d:\pandas_to_excel1.xlsx',sheet_name='new_sheet_name')
x=pd.read_excel('d:\pandas_to_excel.xlsx')
y=pd.read_excel('d:\pandas_to_excel1.xlsx')
z=pd.concat([x,y])
z.to_excel('d:\pandas_to_excel3.xlsx',sheet_name='new_sheet_name')
print('\n')
print(list(d))
print(format(len(d)))
# Out:
#      5.1  3.5  1.4  0.2      Iris-setosa
# 59   5.0  2.0  3.5  1.0  Iris-versicolor
# 61   6.0  2.2  4.0  1.0  Iris-versicolor
# 118  6.0  2.2  5.0  1.5   Iris-virginica
# 67   6.2  2.2  4.5  1.5  Iris-versicolor
# 92   5.0  2.3  3.3  1.0  Iris-versicolor
# ..   ...  ...  ...  ...              ...
# 15   5.4  3.9  1.3  0.4      Iris-setosa
# 13   5.8  4.0  1.2  0.2      Iris-setosa
# 31   5.2  4.1  1.5  0.1      Iris-setosa
# 32   5.5  4.2  1.4  0.2      Iris-setosa
# 14   5.7  4.4  1.5  0.4      Iris-setosa
#
# [149 rows x 5 columns]
#
#
#     a   b   c
# x  ar  br  cr
# y  23  34  67
# z  56  67  78
#
#
#
#
# ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa']
# 149

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

a=np.array([1,20,4,60])
b=np.array([4,32,67,2])
print(plt.plot(a,b,marker='d',ms=8,mec='g',linewidth=3,color='r',linestyle='-.'))
plt.title('graph')
plt.xlabel('index')
plt.ylabel('gain')
plt.scatter(a,b)
plt.grid()
print(plt.show())
# Out:
# ...
# None

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

a=np.array([1,3,4,5,7,8])
b=np.array([4,5,6,2,4,2])
plt.bar(a,b,label='bar graph',width=.5)
plt.xlabel('years')
plt.ylabel('population')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
a=np.array([10,20,40,60])
b=['arc','arav','koki','damu']
explode=[0.2,0,0,0]
plt.pie(a,labels=b,pctdistance=0.9,explode=explode)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
a=np.random.normal(170,10,250)
plt.hist(a,histtype='barstacked')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
a=np.array([10,20,40,60])
plt.barh(a,width=0.8)
plt.show()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
a=np.array([10,20,40,60,65,70,75,80])
b=np.array([20,30,50,40,45,67,80,90])
print(sns.lineplot(a))
plt.show()
print(sns.scatterplot(a))
plt.show()
fig=plt.figure(figsize=(12,8))
fig1=plt.axes(projection='3d')
plot=fig1.scatter3D(a,b)
plt.colorbar(plot)
fig.show()
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
a=np.array([10,20,40,60,65,70,75,80])
b=np.array([20,30,50,40,45,67,80,90])
fig=plt.figure(figsize=(12,8))
fig1=plt.axes(projection='3d')
plot=fig1.scatter3D(a,b)
plt.colorbar(plot)
fig.show()

# %%
import numpy as np
import pandas as pd
a=pd.DataFrame({'A':['ONE','TWO','THREE','FOUR'],'B':['HI','HELLO','BYE','see you'],'C':np.random.randint(8,size=4),'D':np.random.randint(10,size=4)})
df = a.groupby(['A','B']).agg({'C':('mean'),'D':('sum')})
print(a)
print(df)
# Out:
#        A        B  C  D
# 0    ONE       HI  7  3
# 1    TWO    HELLO  7  4
# 2  THREE      BYE  0  8
# 3   FOUR  see you  1  2
#                  C  D
# A     B
# FOUR  see you  1.0  2
# ONE   HI       7.0  3
# THREE BYE      0.0  8
# TWO   HELLO    7.0  4

# %%
import numpy as np
from scipy import stats
df=np.random.normal(1000,2000,3000)

print(np.median(df))
print(np.std(df))
# Out:
# 1074.3424618196689
# 1994.1059932961734

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
df=np.random.randint(1000,2000,3000)
plt.hist(df,50)
plt.show()
df1=np.random.randint(100,300,400)
stats.mode(df1)
# Out:
# ModeResult(mode=171, count=7)

# %%
import numpy as np
from scipy import stats
df=np.random.randint(100,200,250)
#np.var(df)
stats.skew(df)
stats.kurtosis(df)
# Out:
# -1.1571386939538675

# %%
import pandas as pd

data = [1, 2, 3, 4, 5, 20]
df=pd.DataFrame(data,columns=['values'])
print(df['values'].skew())
print(df['values'].kurtosis())
# Out:
# 2.232712657868428
# 5.186154678204437
